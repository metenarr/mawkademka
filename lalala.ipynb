# %% [markdown]
# # 1.1 Подготовка обучающей  и тестовой выборок

# %%
import pandas as pd
import numpy as np #импортируем библиотеки которые потребуются нам для работы

# %%
 pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pandas #устанавливаем сторонние библиотеки для работы
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#io = r'C:\Users\Мария\Desktop\Electric_Vehicle_Population_Data.csv'

# %%
df = pd.read_csv('Electric_Vehicle_Population_Data.csv') #загружаем данные из файлы csv

# %%
df #выводим данные
# Out:
#         VIN (1-10)    County               City State  Postal Code  \
# 0       2C4RC1N71H    Kitsap          Bremerton    WA      98311.0
# 1       2C4RC1N7XL   Stevens           Colville    WA      99114.0
# 2       KNDC3DLCXN    Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0
# 4       1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0
# ...            ...       ...                ...   ...          ...
# 159462  KM8JBDA2XP  Skamania          Underwood    WA      98651.0
# 159463  1G1FZ6S02M    Skagit                Bow    WA      98232.0
# 159464  YV4H60CX2P      King          Sammamish    WA      98029.0
# 159465  5YJ3E1EA7K   Whatcom         Bellingham    WA      98225.0
# 159466  7SAYGDEF6N    Island      Camano Island    WA      98282.0
#
#         Model Year       Make     Model  \
# 0             2017   CHRYSLER  PACIFICA
# 1             2020   CHRYSLER  PACIFICA
# ...

# %% [markdown]
# # 1.2 Анализ и просмотров данных

# %%
df.isnull().sum().sum () #смотрим пропущенное количество значений во всем DataFrame
# Out:
# 390

# %%
df.isnull().sum() #смотрим общее количество пропушщенных значений в столбце
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 361
# DOL Vehicle ID                                         0
# Vehicle Location                                       9
# Electric Utility                                       4
# ...

# %%
df.isnull().sum(axis=1) #делаем подсчект общего количества пропущенных зщначений в строке
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 159462    0
# 159463    0
# 159464    0
# 159465    0
# 159466    0
# Length: 159467, dtype: int64

# %% [markdown]
# # 1.2.2 смотрим различные анамалии в данных

# %%
df.isnull().sum()/ len(df) * 100 #смотрим пропущенных значения в % соотношении
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.002508
# City                                                 0.002508
# State                                                0.000000
# Postal Code                                          0.002508
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.226379
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.005644
# ...

# %%
import seaborn as sns #импортируем библиотеку

# %%
df.dropna(inplace=True) #удаляем пустые значения

# %%
df #выводим
# Out:
#         VIN (1-10)    County               City State  Postal Code  \
# 0       2C4RC1N71H    Kitsap          Bremerton    WA      98311.0
# 1       2C4RC1N7XL   Stevens           Colville    WA      99114.0
# 2       KNDC3DLCXN    Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0
# 4       1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0
# ...            ...       ...                ...   ...          ...
# 159462  KM8JBDA2XP  Skamania          Underwood    WA      98651.0
# 159463  1G1FZ6S02M    Skagit                Bow    WA      98232.0
# 159464  YV4H60CX2P      King          Sammamish    WA      98029.0
# 159465  5YJ3E1EA7K   Whatcom         Bellingham    WA      98225.0
# 159466  7SAYGDEF6N    Island      Camano Island    WA      98282.0
#
#         Model Year       Make     Model  \
# 0             2017   CHRYSLER  PACIFICA
# 1             2020   CHRYSLER  PACIFICA
# ...

# %%
df.isnull().sum()/ len(df) * 100 #еще раз проверяем процентное соотношение
# Out:
# VIN (1-10)                                           0.0
# County                                               0.0
# City                                                 0.0
# State                                                0.0
# Postal Code                                          0.0
# Model Year                                           0.0
# Make                                                 0.0
# Model                                                0.0
# Electric Vehicle Type                                0.0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.0
# Electric Range                                       0.0
# Base MSRP                                            0.0
# Legislative District                                 0.0
# DOL Vehicle ID                                       0.0
# Vehicle Location                                     0.0
# Electric Utility                                     0.0
# ...

# %% [markdown]
# # 1.2.3 поиск выбросов данных и их аномалий

# %%
df.describe().T
# Out:
#                          count          mean           std           min  \
# Postal Code           159101.0  9.825935e+04  3.029946e+02  9.800100e+04
# Model Year            159101.0  2.020194e+03  3.010348e+00  1.997000e+03
# Electric Range        159101.0  6.427121e+01  9.463066e+01  0.000000e+00
# Base MSRP             159101.0  1.224903e+03  8.918602e+03  0.000000e+00
# Legislative District  159101.0  2.926200e+01  1.484400e+01  1.000000e+00
# DOL Vehicle ID        159101.0  2.140532e+08  7.959567e+07  4.385000e+03
# 2020 Census Tract     159101.0  5.303974e+10  1.618356e+07  5.300195e+10
#
#                                25%           50%           75%           max
# Postal Code           9.805200e+04  9.812200e+04  9.837000e+04  9.940300e+04
# Model Year            2.018000e+03  2.021000e+03  2.023000e+03  2.024000e+03
# Electric Range        0.000000e+00  1.400000e+01  8.400000e+01  3.370000e+02
# Base MSRP             0.000000e+00  0.000000e+00  0.000000e+00  8.450000e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159101 entries, 0 to 159466
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         159101 non-null  object
#  1   County                                             159101 non-null  object
#  2   City                                               159101 non-null  object
#  3   State                                              159101 non-null  object
#  4   Postal Code                                        159101 non-null  float64
#  5   Model Year                                         159101 non-null  int64
#  6   Make                                               159101 non-null  object
#  7   Model                                              159101 non-null  object
# ...

# %%
 1 4 11 12 13 14 16

# %%
df.drop(columns=['County', 'Postal Code', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID', 'Vehicle Location', '2020 Census Tract'],inplace=True) #удаляем ненужные признаки

# %%
df #выводим
# Out:
#         VIN (1-10)               City State  Model Year       Make     Model  \
# 0       2C4RC1N71H          Bremerton    WA        2017   CHRYSLER  PACIFICA
# 1       2C4RC1N7XL           Colville    WA        2020   CHRYSLER  PACIFICA
# 2       KNDC3DLCXN             Yakima    WA        2022        KIA       EV6
# 3       5YJ3E1EA0J  Bainbridge Island    WA        2018      TESLA   MODEL 3
# 4       1N4AZ1CP7J           Tumwater    WA        2018     NISSAN      LEAF
# ...            ...                ...   ...         ...        ...       ...
# 159462  KM8JBDA2XP          Underwood    WA        2023    HYUNDAI    TUCSON
# 159463  1G1FZ6S02M                Bow    WA        2021  CHEVROLET   BOLT EV
# 159464  YV4H60CX2P          Sammamish    WA        2023      VOLVO      XC90
# 159465  5YJ3E1EA7K         Bellingham    WA        2019      TESLA   MODEL 3
# 159466  7SAYGDEF6N      Camano Island    WA        2022      TESLA   MODEL Y
#
# ...

# %%
import matplotlib.pyplot as plt #импортируем

# %%
df['Electric Range'].hist(bins=50,color='red');
plt.grid(False) #смотрим на диагремме коллебания

# %%
for i in range(100, 400, 50):
    print(f"lalallalaal{i}:{len(df[df['Electric Range']>i])}") #смотрим разницы в выбросах в данной модели
# Out:
# lalallalaal100:37153
# lalallalaal150:33303
# lalallalaal200:30574
# lalallalaal250:9122
# lalallalaal300:2653
# lalallalaal350:0

# %%
df.drop(index=df[df['Electric Range']>250].index,inplace=True) #удаляем странные выбросы

# %%
for i in range(100, 400, 50):
    print(f"lalallalaal{i}:{len(df[df['Electric Range']>i])}") #проверям что у нас в итоге получилось
# Out:
# lalallalaal100:28031
# lalallalaal150:24181
# lalallalaal200:21452
# lalallalaal250:0
# lalallalaal300:0
# lalallalaal350:0

# %%
df.describe().T #выводим процентное соотношение
# Out:
#                    count         mean        std     min     25%     50%  \
# Model Year      149979.0  2020.217690   3.089759  1997.0  2018.0  2021.0
# Electric Range  149979.0    50.534028  78.585313     0.0     0.0     0.0
#
#                    75%     max
# Model Year      2023.0  2024.0
# Electric Range    73.0   249.0

# %%
df['Model Year'].hist(bins=50,color='red');
plt.grid(False) #cсмотрим вбыросы на другой модели на диаграмме

# %%
for i in range(2000, 2030, 5):
    print(f"lalallalaal{i}:{len(df[df['Model Year']>i])}") #провяем выбросы в числовом значении
# Out:
# lalallalaal2000:149966
# lalallalaal2005:149963
# lalallalaal2010:149919
# lalallalaal2015:134696
# lalallalaal2020:93188
# lalallalaal2025:0

# %%
df.drop(index=df[df['Model Year']>2015].index,inplace=True) #удаляем значения со странными числами

# %%
for i in range(2000, 2030, 5):
    print(f"lalallalaal{i}:{len(df[df['Model Year']>i])}") #смотрим что у нас получилось
# Out:
# lalallalaal2000:15270
# lalallalaal2005:15267
# lalallalaal2010:15223
# lalallalaal2015:0
# lalallalaal2020:0
# lalallalaal2025:0

# %%
for i in range(2000, 2030, 5):
    print(f"lalallalaal{i}:{len(df[df['Model Year']>i])}") #смотрим что у нас получилось
# Out:
# lalallalaal2000:15270
# lalallalaal2005:15267
# lalallalaal2010:15223
# lalallalaal2015:0
# lalallalaal2020:0
# lalallalaal2025:0

# %%
for i in range(2000, 2030, 5):
    print(f"lalallalaal{i}:{len(df[df['Model Year']>i])}") #смотрим что у нас получилось
# Out:
# lalallalaal2000:15270
# lalallalaal2005:15267
# lalallalaal2010:15223
# lalallalaal2015:0
# lalallalaal2020:0
# lalallalaal2025:0
